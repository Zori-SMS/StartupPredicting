# %%
import pandas as pd
data_path = "./cb_db_csv/"

# %%
df_object = pd.read_csv(data_path + 'cb_objects_final.csv', encoding = "ISO-8859-1")
df_object
# Out:
#               id entity_type  entity_id parent_id  \
# 0            c:1     Company          1        \N
# 1           c:10     Company         10        \N
# 2          c:100     Company        100        \N
# 3        c:10000     Company      10000        \N
# 4        c:10001     Company      10001        \N
# 5        c:10002     Company      10002        \N
# 6        c:10003     Company      10003        \N
# 7       c:100042     Company     100042        \N
# 8        c:10005     Company      10005        \N
# 9       c:100062     Company     100062        \N
# 10      c:100068     Company     100068        \N
# 11       c:10008     Company      10008        \N
# 12       c:10009     Company      10009        \N
# 13        c:1001     Company       1001        \N
# 14       c:10010     Company      10010        \N
# 15       c:10011     Company      10011        \N
# 16       c:10012     Company      10012        \N
# 17       c:10013     Company      10013        \N
# ...
