# %%
import pandas as pd

# df_acquiring = pd.read_pickle('./dataframe_cleaned/df_acquiring')
# df_acquired = pd.read_pickle('./dataframe_cleaned/df_acquired')
df_funding = pd.read_pickle('./dataframe_cleaned/df_funding')

# df_ipo = pd.read_pickle('./dataframe_cleaned/df_ipo')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda2\envs\tensorflow\lib\site-packages\pandas\io\pickle.py in try_read(path, encoding)
#     165                 # We want to silencce any warnings about, e.g. moved modules.
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:
#
# ~\Anaconda2\envs\tensorflow\lib\site-packages\pandas\io\pickle.py in read_wrapper(func)
#     148         try:
# --> 149             return func(f)
#     150         finally:
#
# ~\Anaconda2\envs\tensorflow\lib\site-packages\pandas\io\pickle.py in <lambda>(f)
#     165                 # We want to silencce any warnings about, e.g. moved modules.
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:
#
# TypeError: data type "f16" not understood
#
# ...

# %%
df_acquired
# Out:
#                     AUD  CAD  EUR  GBP  JPY  SEK  USD  cash  cash_and_stock  \
# acquired_object_id
# c:22103               0    0    0    0    0    0    1     1               0
# c:54651               0    0    0    0    0    0    1     0               0
# c:159552              0    0    0    0    0    0    1     0               0
# c:329                 0    0    0    0    0    0    1     0               0
# c:2315                0    0    0    0    0    0    1     0               0
# c:54405               0    0    0    0    0    0    1     0               0
# c:8565                0    0    0    0    0    0    1     0               0
# c:86                  0    0    0    0    0    0    1     0               0
# c:45891               0    0    0    0    0    0    1     1               0
# c:193193              0    0    0    0    0    0    1     0               0
# c:192352              0    0    0    0    0    0    1     0               0
# ...
